# %% [markdown]
# # What is Matplotlib?
#
# Matplotlib is a comprehensive visualization library used for creating 2D and 3D plots in Python. Developed by John Hunter in 2003, it remains the most widely used visualization tool in the Python ecosystem today.
#
#
# ## Key Features
#
# * MATLAB-like interface
#
# * High-quality plot generation
#
# * Support for numerous plot types
#
# * Extensive customization options
#
# * LaTeX support
#
# * Interactive plotting capabilities
#
# ## Why Use It?
#
# * Advantages:
#     1. Easy to Learn: MATLAB-like syntax
#
#     2. Flexibility: Ability to customize any type of plot
#
#     3. Wide Adoption: From scientific research to industrial applications
#
#     4. Integration: Compatible with libraries like NumPy and Pandas
#
#     5. Cross-Platform: Works on Windows, Linux, and macOS
#
# * Use Cases:
#
#     1. Data analysis and visualization
#
#     2. Scientific research
#
#     3. Visualizing machine learning results
#
#     4. Financial data analysis
#
#     5. Academic publications

# %% [markdown]
# # Basic Setup and Import
#
#
# ```
# # Installation
# # pip install matplotlib
#
# # Import statements
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
#
# # To display plots inline in Jupyter notebooks
# %matplotlib inline
# ```

# %%
# Import statements
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# To display plots inline in Jupyter notebooks
# %matplotlib inline

# %% [markdown]
# # Basic Plot Types
#
# ## Line Plot

# %%
# Simple line plot
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.figure(figsize=(8, 6))
plt.plot(x, y, marker="o", linestyle=":", color="blue", linewidth=2, markersize=8)
plt.title("Simple Line Plot", fontsize=14)
plt.xlabel("X Axis", fontsize=12)
plt.ylabel("Y Axis", fontsize=12)
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# # Figure and Axes Concepts (OOP Approach)
#
# Matplotlib's core philosophy relies on two main components: Figure and Axes. This Object-Oriented Programming (OOP) approach provides full control over the plot.
#
# | Concept | Definition | Analogy |
# |---------|--------|----------|
# | Figure | The overall window or canvas where plots are drawn. Can contain multiple Axes. | A picture frame or a blank sheet of paper. |
# | Axes | The actual area where the plot is drawn. Where X and Y axes are defined. Each Figure can contain multiple Axes. | The actual drawing area inside the frame. |

# %%
# 1. Create Figure and Axes
# fig: Figure object (canvas)
# ax: Axes object (plotting area)
fig, ax = plt.subplots(figsize=(8, 4))

# 2. Prepare Data
x_data = [1, 2, 3, 4]
y_data = [10, 20, 35, 25]

# 3. Draw the Plot
# Use ax.plot() method to draw on the Axes object
ax.plot(
    x_data, y_data, marker="o", linestyle=":", color="red", linewidth=2, markersize=8
)

ax.set_title("Simple Line Plot", fontsize=14)
ax.set_xlabel("X Axis", fontsize=12)
ax.set_ylabel("Y Axis", fontsize=12)
plt.grid(True, alpha=0.3, linestyle="-", color="blue")

# 4. Display the Plot (Opens window or renders output)
plt.show()

# %% [markdown]
# # Creating Your First Line Plot (plt.plot())
#
# Let's create a basic line plot using plt.plot() and configure basic settings. For simplicity, we can also demonstrate the Procedural approach here (single-line plotting).

# %%
# Simple line plot - procedural method

# Create dataset (e.g., sine wave)
x = np.linspace(0, 10, 100)  # 100 evenly spaced points from 0 to 10
y = np.sin(x)

# Single line plotting (Matlab/plt.plot() style)
# Matplotlib automatically creates a Figure and an Axes in the background.
plt.plot(x, y)
plt.show()

# %%
# Line Customization
# Back to OOP Approach
fig, ax = plt.subplots(figsize=(8, 4))  # Set figure size with figsize

# Customize the line
# 'r--' -> Red color, dashed line
# linewidth -> Line thickness
# label -> Label for legend
ax.plot(x, y, "r--", linewidth=2, label="Sine Wave")

# Add a second line (Cosine)
ax.plot(
    x, np.cos(x), "b-", linewidth=1, label="Cosine Wave"
)  # 'b-' -> Blue color, solid line

plt.show()

# %% [markdown]
# # Customizing and Labeling the Plot
#
# Adding titles, axis labels, and legends to improve plot readability.

# %%
# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create Figure and Axes
fig, ax = plt.subplots(figsize=(10, 5))  # figsize 10x5 inches

# Draw the plot
ax.plot(x, y, color="purple", linestyle="-", label="Sine Plot")

# 1. Add Title
# Adjust font size with fontsize
ax.set_title("Sine Function Over Time", fontsize=16, color="darkblue")

# 2. Add Axis Labels
ax.set_xlabel("Time (t)", fontsize=12)
ax.set_ylabel("Amplitude (A)", fontsize=12)

# 3. Add Legend (Displays labels defined via label parameter)
ax.legend(loc="lower left")  # loc: legend position

# 4. Set Axis Limits
# Defines min/max values displayed on the plot
ax.set_xlim(0, 10)
ax.set_ylim(-1.5, 1.5)

# 5. Add Grid Lines
ax.grid(True, linestyle=":", alpha=0.6)

plt.show()

# %% [markdown]
# # Saving the Plot
# Saving generated plots to a file is critical, especially for presentations and reports.

# %%
# Done using the fig (Figure) object
fig.savefig(
    "sine_plot_detailed.png",
    dpi=300,  # High resolution (dots per inch)
    bbox_inches="tight",
)  # Removes unnecessary whitespace around the plot

# %% [markdown]
# # Scatter Plot

# %%
# To visualize the relationship or correlation between two continuous variables.

# Generate random data
np.random.seed(42)  # For reproducibility
height = np.random.normal(170, 10, 50)  # Mean 170, Std Dev 10
weight = height * 0.6 + np.random.normal(5, 5, 50)  # Weight correlated with height

fig, ax = plt.subplots(figsize=(8, 5))

# Draw scatter plot
# s: marker size, c: marker color, alpha: transparency
ax.scatter(height, weight, s=50, c="darkgreen", alpha=0.7)

ax.set_title("Height vs Weight Relationship (Scatter Plot)")
ax.set_xlabel("Height (cm)")
ax.set_ylabel("Weight (kg)")
ax.grid(True, linestyle="--")

plt.show()

# %%
# Scatter plot
np.random.seed(42)
x = np.random.randn(100)
y = np.random.randn(100)
colors = np.random.rand(100)
sizes = 1000 * np.random.rand(100)

plt.figure(figsize=(10, 8), dpi=100)  # 10x100 by 8x100 pixels
plt.scatter(x, y, c=colors, s=sizes, alpha=0.7, cmap="viridis")
plt.colorbar(label="Color Value")
plt.title("Scatter Plot", fontsize=14)
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.show()

# %% [markdown]
# # Bar Plot

# %%
# Used to compare categorical data. Categories are on the X-axis,
# and corresponding values (count, average, etc.) are on the Y-axis.

# Command: ax.bar(categories, values)

# Categorical data
products = ["A", "B", "C", "D", "E"]
sales = [250, 400, 150, 350, 500]

fig, ax = plt.subplots(figsize=(8, 5))

# Draw bar plot
ax.bar(products, sales, color=["skyblue", "salmon", "lightgreen", "gold", "grey"])

ax.set_title("Monthly Product Sales (Bar Chart)")
ax.set_xlabel("Product Category")
ax.set_ylabel("Total Units Sold")

plt.show()

# %%
# Vertical bar chart
categories = ["A", "B", "C", "D", "E"]
values = [23, 45, 56, 78, 33]

plt.figure(figsize=(10, 6))
bars = plt.bar(categories, values, color=["red", "blue", "green", "orange", "purple"])
plt.title("Vertical Bar Chart", fontsize=14)
plt.xlabel("Categories")
plt.ylabel("Values")

# Add value labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2.0,
        height,
        f"{height}",
        ha="center",
        va="bottom",
    )

plt.show()

# %%
# Horizontal bar chart
# Data
categories = ["A", "B", "C", "D", "E"]
values = [23, 45, 56, 78, 33]

# Figure size
plt.figure(figsize=(10, 6))

# Horizontal bar chart
bars = plt.barh(categories, values, color=["red", "blue", "green", "orange", "purple"])

# Title and labels
plt.title("Horizontal Bar Chart", fontsize=14)
plt.xlabel("Values")
plt.ylabel("Categories")

# Add value labels at the end of bars
for bar in bars:
    width = bar.get_width()  # bar length (value)
    plt.text(
        width + 1,  # place text just right of the bar
        bar.get_y() + bar.get_height() / 2,  # center vertically
        f"{width}",
        va="center",
    )

plt.show()

# %% [markdown]
# # Histogram

# %%
# Purpose: To show the distribution (frequency) of a continuous variable.
# Data is grouped into intervals (bins) and observation counts are shown with bars.

# Command: ax.hist(data, bins=...)

# Random normally distributed data
data = np.random.normal(loc=50, scale=10, size=1000)  # Mean 50, Std Dev 10

fig, ax = plt.subplots(figsize=(8, 5))

# Draw histogram
# bins: Specifies number of intervals (bars)
ax.hist(
    data,
    bins=20,
    color="teal",
    edgecolor="black",  # Bar border color
    alpha=0.8,
)

ax.set_title("Exam Score Distribution (Histogram)")
ax.set_xlabel("Score Range")
ax.set_ylabel("Frequency (Student Count)")

plt.show()

# %%
# Histogram
np.random.seed(42)
data = np.random.normal(0, 1, 1000)

plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, alpha=0.7, color="skyblue", edgecolor="black")
plt.title("Histogram", fontsize=14)
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# # Pie Chart

# %%
# Pie chart
labels = ["Python", "Java", "C++", "JavaScript", "Other"]
percentages = [35, 25, 20, 15, 5]
colors = ["#ff9999", "#66b3ff", "#99ff99", "#ffcc99", "#c2c2f0"]

plt.figure(figsize=(8, 8))
plt.pie(
    percentages,
    labels=labels,
    colors=colors,
    autopct="%1.1f%%",
    startangle=90,
    explode=[0.05, 0.1, 0, 0, 0],
    shadow=True,
)
plt.title("Programming Language Distribution")
plt.show()

# %% [markdown]
# # Subplots
#
# Multiple Plot Layouts (Subplots)
#
#
# Description: Often we need to draw multiple plots in a single window to examine different aspects of data simultaneously. In Matplotlib, this is called a subplot.
#
# Grid Layout with `plt.subplots()`
# `plt.subplots(nrows, ncols)` is the most common method. It automatically returns a Figure and specified number of Axes objects.
#
# Example: 2x2 Grid Layout

# %%
# Create 4 Axes (ax) in 2 rows and 2 columns on a single Figure (fig)
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))
# ax is now a 2D NumPy array, accessed via indexing: ax[row, col]

# Data
x = np.linspace(0, 5, 50)
y1 = x
y2 = x**2
y3 = np.sqrt(x)
y4 = x**3

# Top Left (0, 0)
ax[0, 0].plot(x, y1, "r")
ax[0, 0].set_title("Linear (y=x)")

# Top Right (0, 1)
ax[0, 1].plot(x, y2, "g")
ax[0, 1].set_title("Quadratic (y=x^2)")

# Bottom Left (1, 0)
ax[1, 0].plot(x, y3, "b")
ax[1, 0].set_title("Square Root (y=sqrt(x))")

# Bottom Right (1, 1)
ax[1, 1].plot(x, y4, "purple")
ax[1, 1].set_title("Cubic (y=x^3)")

# Main title for all plots
fig.suptitle("Various Mathematical Functions", fontsize=16)

# Adjust spacing to prevent overlapping
fig.tight_layout(pad=3.0)

plt.show()

# %% [markdown]
# Asymmetric Layouts with add_subplot()
# Sometimes asymmetric layouts are needed. In such cases, each Axes can be added individually.

# %%
fig = plt.figure(figsize=(9, 6))

# (num_rows, num_cols, position)
# Plot 1: Occupies full left side (row 1 of 2 rows, 1 col)
ax1 = fig.add_subplot(2, 2, 1)  # Top Left
ax1.plot(x, y1, label="Plot 1")

# Plot 2: Top Right
ax2 = fig.add_subplot(2, 2, 2)
ax2.plot(x, y2, label="Plot 2")

# Plot 3: Occupies full bottom side (row 2 of 2 rows, 1 col)
ax3 = fig.add_subplot(2, 1, 2)
ax3.plot(x, y3, label="Plot 3")

fig.tight_layout()
plt.show()

# %%
# 2x2 subplot layout
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Generate data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = np.exp(x / 10)

# Plot 1
axes[0, 0].plot(x, y1, "r-")
axes[0, 0].set_title("Sine Function")
axes[0, 0].grid(True)

# Plot 2
axes[0, 1].plot(x, y2, "b-")
axes[0, 1].set_title("Cosine Function")
axes[0, 1].grid(True)

# Plot 3
axes[1, 0].plot(x, y3, "g-")
axes[1, 0].set_title("Tangent Function")
axes[1, 0].grid(True)
axes[1, 0].set_ylim(-5, 5)

# Plot 4
axes[1, 1].plot(x, y4, "m-")
axes[1, 1].set_title("Exponential Function")
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Style and Appearance Customization
#
# # Style Templates

# %%
# View available styles
print(plt.style.available)

# Apply style
plt.style.use("seaborn-v0_8")

# Example plot
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y1, label="sin(x)", linewidth=2)
plt.plot(x, y2, label="cos(x)", linewidth=2)
plt.title("Styled Plot", fontsize=16)
plt.xlabel("x", fontsize=12)
plt.ylabel("y", fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# # Detailed Customization

# %%
# Detailed customization example
fig, ax = plt.subplots(figsize=(12, 8))

# Generate data
x = np.linspace(0, 2 * np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Draw plots
ax.plot(
    x,
    y1,
    label="sin(x)",
    color="red",
    linewidth=1,
    linestyle="-",
    marker="o",
    markersize=4,
)
ax.plot(
    x,
    y2,
    label="cos(x)",
    color="blue",
    linewidth=1,
    linestyle="--",
    marker="s",
    markersize=4,
)

# Axis customization
ax.set_xlabel("X Values", fontsize=14, fontweight="bold")
ax.set_ylabel("Y Values", fontsize=14, fontweight="bold")
ax.set_title("Trigonometric Functions", fontsize=16, fontweight="bold")

# Axis limits
ax.set_xlim(0, 2 * np.pi)
ax.set_ylim(-1.5, 1.5)

# Grid lines
ax.grid(True, which="both", alpha=0.3, linestyle="-", linewidth=0.5)

# Spines (axis borders)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_linewidth(2)
ax.spines["bottom"].set_linewidth(2)

# Legend
ax.legend(loc="upper right", frameon=True, fancybox=True, shadow=True, fontsize=12)

# Reference lines
ax.axhline(y=0, color="k", linestyle="-", alpha=0.3)
ax.axvline(x=np.pi, color="gray", linestyle=":", alpha=0.5, label="x=π")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 3D Plots

# %%
# 3D surface plot
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection="3d")

# Generate data
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# Draw 3D surface
surface = ax.plot_surface(X, Y, Z, cmap="viridis", alpha=0.9)

# Axis labels
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("3D Surface Plot")

# Colorbar
fig.colorbar(surface, ax=ax, shrink=0.5, aspect=5)

plt.show()

# %% [markdown]
# # Integration with Pandas

# %%
# Usage with Pandas DataFrame
df = pd.DataFrame(
    {
        "Months": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
        "Sales": [150, 200, 180, 300, 250, 400],
        "Expenses": [100, 120, 110, 150, 130, 180],
        "Profit": [50, 80, 70, 150, 120, 220],
    }
)

# Create plots directly from DataFrame
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Bar chart
df.plot(x="Months", y=["Sales", "Expenses"], kind="bar", ax=ax1)
ax1.set_title("Monthly Sales and Expenses")
ax1.set_ylabel("Amount")

# Line chart
df.plot(x="Months", y="Profit", kind="line", marker="o", ax=ax2, color="green")
ax2.set_title("Monthly Profit")
ax2.set_ylabel("Profit Amount")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Advanced Features
#
# # Animations

# %%
from matplotlib.animation import FuncAnimation

# Create figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

# X data (100 points between 0 and 4π)
x = np.linspace(0, 4 * np.pi, 100)

# Initial sine wave
(line,) = ax.plot(x, np.sin(x))

# Fix Y axis limits (otherwise it flickers)
ax.set_ylim(-1.5, 1.5)


# Function called at each frame
def animate(frame):
    line.set_ydata(np.sin(x + frame / 10))  # shift phase
    return (line,)


# Create animation
ani = FuncAnimation(fig, animate, frames=100, interval=50, blit=True)

# Display
plt.show()

ani.save("sine_animation.gif", writer="pillow", fps=20)

# %%
from IPython.display import Image

Image(open("sine_animation.gif", "rb").read())

# %% [markdown]
# # Specialized Plots

# %%
# Box plot and Violin plot
np.random.seed(42)
data1 = np.random.normal(0, 1, 100)
data2 = np.random.normal(1, 1.5, 100)
data3 = np.random.normal(-1, 0.5, 100)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Box plot
ax1.boxplot([data1, data2, data3])
ax1.set_title("Box Plot")
ax1.set_xticklabels(["Group 1", "Group 2", "Group 3"])

# Violin plot
ax2.violinplot([data1, data2, data3])
ax2.set_title("Violin Plot")
ax2.set_xticks([1, 2, 3])
ax2.set_xticklabels(["Group 1", "Group 2", "Group 3"])

plt.tight_layout()
plt.show()

# %% [markdown]
# # Saving and Exporting

# %%
# Saving plots
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.title("Plot to be Saved")

# Save in different formats
plt.savefig("plot.png", dpi=300, bbox_inches="tight")  # PNG format
plt.savefig("plot.pdf", bbox_inches="tight")  # PDF format
plt.savefig("plot.svg", bbox_inches="tight")  # SVG format

plt.show()

# %% [markdown]
# # Summary
# Matplotlib is a powerful and flexible library for data visualization in Python. Key features:
#
# Easy to use with MATLAB-like syntax
#
# Wide range of plot types (line, scatter, bar, histogram, pie, etc.)
#
# Highly customizable
#
# 3D plotting support
#
# Integration with Pandas and NumPy
#
# Professional quality output

# %% [markdown]
# # 1. What is Seaborn?
#
# Seaborn is a high-level Python library built on top of Matplotlib, designed for statistical data visualization. Developed by Michael Waskom, it is optimized specifically for plots used in statistical analyses.
#
# * Key Features:
#
# 1. Beautiful plots with less code compared to Matplotlib
#
# 2. Direct integration with Pandas DataFrames
#
# 3. Automatic statistical computations
#
# 4. Advanced color palettes
#
# 5. Multivariate data visualization support

# %% [markdown]
# # 2. Why Use Seaborn?
#
# * Advantages:
# 1. Visual Quality: Aesthetically pleasing plots by default
#
# 2. Code Simplicity: Do more with less code
#
# 3. Statistical Focus: Special functions for statistical analyses
#
# 4. Color Palettes: Advanced and meaningful color schemes
#
# 5. Pandas Integration: Work directly with DataFrames

# %% [markdown]
# # Differences from Matplotlib:
# * Higher-level API
#
# * Automatic statistical calculations
#
# * More modern and clean appearance
#
# * Dataset-oriented workflow

# %% [markdown]
# # 3. Basic Setup and Import
#
#
# ```
# # Installation
# # pip install seaborn
#
# # Import statements
# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
#
# # Default style setting
# sns.set_theme() # Themes: darkgrid, whitegrid, dark, white, ticks
# ```

# %%
# Installation
# pip install seaborn

# Import statements
import seaborn as sns

# Default style setting
sns.set_theme()  # Themes: darkgrid, whitegrid, dark, white, ticks

# %% [markdown]
# # Basic Imports and Data Loading

# %%
# Load one of Seaborn's built-in example datasets
# This dataset is frequently used in data science.
df_tips = sns.load_dataset("tips")
print("First 5 Rows of Dataset:")
print(df_tips.head())
# Out:
# First 5 Rows of Dataset:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 4. Basic Plot Types and Usage
#
# # 4.1 Line Plot

# %%
# Generate sample data
np.random.seed(42)
time = pd.date_range("2023-01-01", periods=100, freq="D")
values = np.cumsum(np.random.randn(100)) + 100

df = pd.DataFrame({"Date": time, "Value": values})

# Seaborn line plot
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x="Date", y="Value", marker="o", markersize=4, linewidth=2.5)
plt.title("Time Series Data", fontsize=14, fontweight="bold")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4.2 Scatter Plot

# %%
# Using built-in dataset
tips = sns.load_dataset("tips")

plt.figure(figsize=(10, 8))
scatter = sns.scatterplot(
    data=tips,
    x="total_bill",
    y="tip",
    hue="size",
    size="size",
    palette="viridis",
    alpha=0.7,
)
plt.title("Tip vs Total Bill", fontsize=14)
plt.xlabel("Total Bill ($)")
plt.ylabel("Tip ($)")
plt.legend(title="Party Size", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4.3 Bar Plot
#
# Unlike Matplotlib's bar, Seaborn's barplot shows the mean value (and error bars by default) for each category.

# %%
fig, ax = plt.subplots(figsize=(8, 5))

# Mean of total_bill grouped by day
# estimator=np.mean (default: calculates mean)
sns.barplot(
    data=df_tips,
    x="day",
    y="total_bill",
    hue="sex",  # Compare by Male and Female
    palette="Pastel1",
    ax=ax,
)

ax.set_title("Average Daily Bill Amount by Gender")
ax.set_xlabel("Day of Week")
ax.set_ylabel("Average Bill ($)")

plt.show()

# %%
# Grouped bar chart
plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(
    data=tips,
    x="day",
    y="total_bill",
    hue="sex",
    palette=["lightblue", "pink"],
    errorbar=None,
    capsize=0.05,
    err_kws={"linewidth": 1.5},
)
plt.title("Average Bill by Day (by Gender)", fontsize=14)
plt.xlabel("Day")
plt.ylabel("Average Total Bill ($)")
plt.legend(title="Gender")
plt.show()

# %% [markdown]
# # 4.4 Histogram and KDE (Kernel Density Estimation)
#
# Seaborn's histplot (similar to Matplotlib's hist) and kdeplot (Kernel Density Estimation) show the shape of the distribution.
#
# Statistically rich plots summarizing distributions of categorical and continuous variables. These plots show quartiles, median, and outliers of a variable.

# %%
# Examine distribution of total_bill variable
fig, ax = plt.subplots(figsize=(8, 4))

# Histogram (Seaborn style, more aesthetic than Matplotlib)
sns.histplot(
    data=df_tips,  # Data source (Pandas DataFrame)
    x="total_bill",  # Column for X axis
    bins=15,
    kde=True,  # Add density estimation line
    color="darkorange",
    ax=ax,
)

ax.set_title("Total Bill Distribution (Histplot + KDE)")
plt.show()

# Density Plot Only (KDE)
fig, ax = plt.subplots(figsize=(8, 4))
sns.kdeplot(data=df_tips, x="total_bill", fill=True, color="teal", ax=ax)
ax.set_title("Total Bill Kernel Density Estimation (KDE Plot)")
plt.show()

# %%
# Histogram and KDE
plt.figure(figsize=(12, 5))

# Subplots
plt.subplot(1, 2, 1)
sns.histplot(data=tips, x="total_bill", bins=20, kde=True, color="skyblue")
plt.title("Histogram with KDE")

plt.subplot(1, 2, 2)
sns.kdeplot(
    data=tips, x="total_bill", hue="time", fill=True, palette="pastel", alpha=0.6
)
plt.title("KDE Plot (by Time)")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4.5 Box Plot and Violin Plot
#
# Box Plot: Summarizes data via median, quartiles, and outliers.
# `sns.boxplot(x=category, y=value)`
#
# Violin Plot: Provides same summary info as box plot but also shows distribution shape (density estimation) on sides. Offers more information than Box Plot.
#
# Command: `sns.violinplot(x=category, y=value)`

# %%
# Data: total_bill distribution by time (Lunch vs Dinner)
fig, ax = plt.subplots(figsize=(8, 5))

sns.boxplot(
    data=df_tips,
    x="time",  # Categorical variable (X axis)
    y="total_bill",  # Numerical variable (Y axis)
    palette="Set2",  # Color palette
    ax=ax,
)

ax.set_title("Lunch vs Dinner Bill Comparison (Box Plot)")
ax.set_xlabel("Meal Time")
ax.set_ylabel("Total Bill ($)")

plt.show()
# Out:
# <positron-console-cell-46>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Violin

fig, ax = plt.subplots(figsize=(8, 5))

sns.violinplot(
    data=df_tips,
    x="day",  # Days of week
    y="tip",  # Tip amount
    palette="viridis",
    ax=ax,
)

ax.set_title("Tip Distribution by Day of Week (Violin Plot)")
ax.set_xlabel("Day of Week")
ax.set_ylabel("Tip Amount ($)")

plt.show()
# Out:
# <positron-console-cell-47>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Box plot vs violin plot comparison
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.boxplot(data=tips, x="day", y="total_bill", hue="smoker", palette="Set2")
plt.title("Box Plot")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")

plt.subplot(1, 2, 2)
sns.violinplot(
    data=tips,
    x="day",
    y="total_bill",
    hue="smoker",
    split=True,
    palette="Set2",
    inner="quartile",
)
plt.title("Violin Plot")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4.6 Point Plot
# Similar to bar charts but shows means as points on vertical lines. Useful for comparing multiple categories on a single axis.

# %% [markdown]
# # 5. Statistical Plots
#
# # 5.1 Pair Plot

# %%
# Pair plot - multivariate analysis
iris = sns.load_dataset("iris")

pair_grid = sns.pairplot(
    iris, hue="species", palette="husl", diag_kind="kde", markers=["o", "s", "D"]
)
pair_grid.fig.suptitle("Iris Dataset - Pair Plot", y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# # 5.2 Heatmap
#
# Used to visualize correlation between multiple numerical variables in a single matrix.

# %%
# Select only numerical columns and compute correlation matrix
df_corr = df_tips[["total_bill", "tip", "size"]].corr()

fig, ax = plt.subplots(figsize=(6, 5))

# Draw Heatmap
sns.heatmap(
    df_corr,
    annot=True,  # Show correlation values inside cells
    cmap="viridis",  # Color palette
    fmt=".2f",  # Number format (2 decimals)
    linewidths=0.5,  # Line thickness
    cbar=True,  # Show color bar
    ax=ax,
)

ax.set_title("Correlation Matrix of Numerical Variables")
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(10, 8))

# Calculate correlation matrix
corr_matrix = iris.select_dtypes(include=[np.number]).corr()

# Create heatmap
heatmap = sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
    center=0,
    square=True,
    fmt=".2f",
    cbar_kws={"shrink": 0.8},
)
plt.title("Iris Dataset - Correlation Matrix", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5.3 Joint Plot

# %%
# Joint plot - combination of scatter and histogram
joint = sns.jointplot(
    data=iris,
    x="sepal_length",
    y="sepal_width",
    hue="species",
    palette="dark",
    alpha=0.7,
    kind="scatter",
    height=8,
)
joint.fig.suptitle("Sepal Length vs Sepal Width", y=1.02, fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 6. Categorical Plots
# # 6.1 Cat Plot

# %%
# Catplot - flexible categorical plots
plt.figure(figsize=(12, 6))
cat_plot = sns.catplot(
    data=tips,
    x="day",
    y="total_bill",
    hue="sex",
    kind="box",
    col="time",
    palette="pastel",
    height=6,
    aspect=1.2,
)
cat_plot.fig.suptitle("Bill Distribution (by Day and Time)", y=1.02)
plt.show()

# %% [markdown]
# # 6.2 Count Plot
#
# Used solely to show frequency (count) of categorical variables. Automatically counts Y axis.

# %%
fig, ax = plt.subplots(figsize=(8, 5))

# Counts observations in 'day' category
sns.countplot(
    data=df_tips,
    x="day",
    order=["Thur", "Fri", "Sat", "Sun"],  # Define day order
    color="lightblue",
    edgecolor="black",
    ax=ax,
)

ax.set_title("Daily Observation Counts in Dataset")
ax.set_xlabel("Day of Week")
ax.set_ylabel("Observation Count (Frequency)")

plt.show()

# %%
# Count plot - categorical variable frequencies
plt.figure(figsize=(10, 6))
count_plot = sns.countplot(
    data=tips, x="day", hue="sex", palette="Set3", saturation=0.8
)
plt.title("Visit Count by Day (by Gender)", fontsize=14)
plt.xlabel("Day")
plt.ylabel("Count")

# Add value labels on bars
for container in count_plot.containers:
    count_plot.bar_label(container, fontsize=10)

plt.show()

# %% [markdown]
# # 7. Style and Appearance Customization
# # 7.1 Themes and Color Palettes
#
# Unlike Matplotlib's scatter, Seaborn's scatterplot allows visualizing additional dimensions using extra categorical variables (e.g., color, size, or shape).

# %%
# Reload dataset
df_tips = sns.load_dataset("tips")

fig, ax = plt.subplots(figsize=(10, 6))

# Plot relationship between total_bill (X) and tip (Y)
# hue: Color points by 'time' category
# style: Change marker shape by 'smoker' category
sns.scatterplot(
    data=df_tips,
    x="total_bill",
    y="tip",
    hue="time",  # Show 3rd variable via color
    style="smoker",  # Show 4th variable via shape
    s=80,  # Marker size
    ax=ax,
)

ax.set_title("Total Bill vs Tip Relationship (by Time and Smoker Status)")
ax.legend(title="Meal Time", loc="upper left")

plt.show()

# %%
# Trying different themes
themes = ["darkgrid", "whitegrid", "dark", "white", "ticks"]
palettes = ["deep", "muted", "pastel", "bright", "dark", "colorblind"]

# Color palette examples
plt.figure(figsize=(15, 10))

for i, (theme, palette) in enumerate(zip(themes[:3], palettes[:3])):
    sns.set_theme(style=theme)

    plt.subplot(2, 3, i + 1)
    sns.scatterplot(
        data=iris, x="sepal_length", y="sepal_width", hue="species", palette=palette
    )
    plt.title(f"Theme: {theme}, Palette: {palette}")

sns.set_theme(style="whitegrid")  # Return to default theme
plt.tight_layout()
plt.show()

# %% [markdown]
# # 7.2 Detailed Customization

# %%
# Detailed customization example
with sns.axes_style("whitegrid"):
    plt.figure(figsize=(12, 8))

    # Custom color palette
    custom_palette = sns.color_palette("husl", 3)

    # Violin plot with swarm plot
    ax = sns.violinplot(
        data=iris,
        x="species",
        y="petal_length",
        palette=custom_palette,
        inner=None,
        alpha=0.7,
    )
    sns.swarmplot(
        data=iris, x="species", y="petal_length", color="black", alpha=0.8, size=3
    )

    # Plot customization
    ax.set_title(
        "Petal Length Distribution by Iris Species",
        fontsize=16,
        fontweight="bold",
        pad=20,
    )
    ax.set_xlabel("Iris Species", fontsize=12, fontweight="bold")
    ax.set_ylabel("Petal Length (cm)", fontsize=12, fontweight="bold")

    # Remove spines
    sns.despine(left=True, bottom=True)

plt.tight_layout()
plt.show()
# Out:
# <positron-console-cell-59>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# # 7.3 Setting Plot Style
#
# Seaborn offers ready-made styles for visual elements like background, grid lines, and borders.
#
# ## 🎨 Seaborn Style Settings
#
# | Style | Description |
# |------|-----------|
# | `whitegrid` | White background with grid lines (very popular). |
# | `darkgrid` | Dark background with grid lines. |
# | `white` | White background, no grid. |
# | `dark` | Dark background, no grid. |
# | `ticks` | White background with small tick marks on axes. |

# %%
# Change plot style (e.g., white grid)
sns.set_style("whitegrid")

# Draw example Box Plot
df_tips = sns.load_dataset("tips")

plt.figure(figsize=(8, 5))
sns.boxplot(data=df_tips, x="day", y="total_bill")
plt.title("Box Plot with White Grid Style")

# Change style and draw another plot
sns.set_style("ticks")
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df_tips, x="total_bill", y="tip")
plt.title("Scatter Plot with Ticks Style")

plt.show()

# Note: Usually a style is set at beginning and used throughout.
sns.set_style("whitegrid")  # Return to standard style

# %% [markdown]
# # 7.4 Using Color Palettes
# Seaborn offers hundreds of color palettes. Palettes can be selected based on data type (sequential, categorical, diverging).

# %%
# Some popular palettes: 'viridis', 'magma', 'Set1', 'Pastel2', 'rocket'

plt.figure(figsize=(8, 5))

# Use 'rocket' (dark to light) sequential palette
sns.barplot(data=df_tips, x="day", y="tip", palette="rocket")

plt.title("Bar Plot with Rocket Palette")
plt.show()

# Use 'Set2' (categorical, distinct colors) palette
plt.figure(figsize=(8, 5))
sns.violinplot(data=df_tips, x="time", y="total_bill", palette="Set2")
plt.title("Violin Plot with Set2 Palette")
plt.show()
# Out:
# <positron-console-cell-61>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <positron-console-cell-61>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# # 8. Regression Plots
# # 8.1 Reg Plot
# These plots show linear relationship between two variables while automatically adding best-fit regression line and confidence interval.

# %%
fig, ax = plt.subplots(figsize=(8, 5))

# Show linear relationship between total_bill and tip
# ci=95: Show 95% confidence interval (default)
sns.regplot(
    data=df_tips,
    x="total_bill",
    y="tip",
    scatter_kws={"color": "teal", "alpha": 0.7},  # Point settings
    line_kws={"color": "red"},  # Line settings
    ax=ax,
)

ax.set_title("Tip Prediction with Regression Line")
plt.show()

# %%
# Regression plots
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.regplot(
    data=tips,
    x="total_bill",
    y="tip",
    scatter_kws={"alpha": 0.5},
    line_kws={"color": "red"},
)
plt.title("Simple Linear Regression")

plt.subplot(1, 3, 2)
sns.regplot(data=tips, x="total_bill", y="tip", lowess=True, scatter_kws={"alpha": 0.5})
plt.title("LOWESS Regression")

plt.subplot(1, 3, 3)
sns.residplot(data=tips, x="total_bill", y="tip", scatter_kws={"alpha": 0.5})
plt.title("Residual Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 8.2 LM Plot (Linear Model Plot)

# %%
# LM plot - regression by groups
lm = sns.lmplot(
    data=tips,
    x="total_bill",
    y="tip",
    hue="smoker",
    col="time",
    row="sex",
    palette="Set1",
    height=4,
    aspect=1.2,
    ci=95,
)
lm.fig.suptitle("Tip Regression Analysis (by Groups)", y=1.02)
plt.show()

# %% [markdown]
# # 9. Multivariate Analysis
# # 9.1 Facet Grid
# FacetGrid or its high-level counterparts (relplot, catplot) split a large dataset by values of one or two categorical variables and draw same plot for each subset. This allows quick comparison of differences between subgroups.

# %%
# Example: Tip Distribution by Size Across Days
# sns.catplot places a categorical plot type (e.g., boxplot) into FacetGrid.
sns.catplot(
    data=df_tips,
    x="time",  # X axis: Meal Time
    y="tip",  # Y axis: Tip Amount
    kind="box",  # Plot type (boxplot, violin, bar etc.)
    col="day",  # Split columns by 'day' category
    col_wrap=2,  # Limit max columns to 2
    height=4,  # Height of each subplot
    aspect=1.2,  # Aspect ratio of each subplot
    palette="muted",
)

plt.suptitle("Meal Time and Tip Distribution (Separated by Day)", y=1.02)
plt.show()
# Out:
# <positron-console-cell-65>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# FacetGrid - advanced multiple plots
g = sns.FacetGrid(
    tips, col="time", row="smoker", hue="sex", palette="Set2", height=4, aspect=1.2
)
g.map(sns.scatterplot, "total_bill", "tip", alpha=0.7)
g.add_legend()
g.fig.suptitle("Multidimensional Data Analysis", y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# # 9.2 Cluster Map

# %%
# Cluster map - hierarchical clustering
plt.figure(figsize=(12, 8))

# Select numerical columns
numeric_iris = iris.select_dtypes(include=[np.number])

# Create cluster map
cluster_grid = sns.clustermap(
    numeric_iris, standard_scale=1, cmap="viridis", figsize=(10, 8)
)
cluster_grid.fig.suptitle("Iris Dataset - Cluster Map", y=1.02)
plt.show()

# %% [markdown]
# # 10. Advanced Features
# # 10.1 Distribution Plot

# %%
# Advanced distribution plot
plt.figure(figsize=(12, 6))

# Distribution plot
sns.displot(
    data=tips,
    x="total_bill",
    hue="day",
    kind="kde",
    palette="tab10",
    height=6,
    aspect=1.5,
)
plt.title("Bill Distribution by Day")
plt.show()

# %% [markdown]
# # 10.2 Ridge Plot

# %%
# Ridge plot (required libraries)
# pip install joypy

import joypy

# Ridge plot-like visualization
plt.figure(figsize=(12, 8))

# Violin plot with ridge plot effect
sns.violinplot(
    data=iris,
    y="species",
    x="sepal_length",
    palette="light:g",
    inner=None,
    saturation=0.5,
)
sns.stripplot(
    data=iris, y="species", x="sepal_length", size=3, color="black", alpha=0.3
)
plt.title("Ridge Plot-Like Visualization", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# <positron-console-cell-73>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# # 11. Deep Integration with Pandas

# %%
# Complete analysis with Pandas DataFrame
# Load dataset
mpg = sns.load_dataset("mpg")

# Complete analysis
g = sns.PairGrid(mpg.select_dtypes(include=[np.number]).iloc[:, :4])
g.map_upper(sns.scatterplot, alpha=0.6)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)
g.fig.suptitle("MPG Dataset - Multivariate Analysis", y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# # 12. Saving and Exporting

# %%
# Saving plots
plt.figure(figsize=(10, 6))
final_plot = sns.boxplot(data=mpg, x="origin", y="mpg", palette="Set3")
plt.title("MPG Distribution by Country of Origin", fontsize=14)

# High quality save
plt.savefig(
    "seaborn_plot.png",
    dpi=300,
    bbox_inches="tight",
    facecolor="white",
    edgecolor="none",
)
plt.savefig("seaborn_plot.pdf", bbox_inches="tight")

plt.show()
# Out:
# <positron-console-cell-71>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# ## Summary and Best Practices
# Seaborn Strengths:
#
# * Ideal for rapid prototyping
#
# * Optimized for statistical visualization
#
# * Beautiful default settings
#
# * Excellent compatibility with Pandas
#
# * Multivariate analysis support
#
#
# Tips:
#
# * Set theme at start with sns.set_theme()
#
# * Quick start using built-in datasets
#
# * Group data using hue parameter
#
# * Quick exploratory analysis with pairplot
#
# * Flexible categorical plots with catplot
#
# When to Use Seaborn?
#
# * For quick and beautiful plots
#
# * In statistical analyses
#
# * When working with Pandas DataFrames
#
# * With grouped data
#
# * In exploratory data analysis
#
#
# Seaborn offers a more practical solution than Matplotlib especially for statistical analysis and rapid data exploration. Best results are achieved by using both together.

# %% [markdown]
# Mini Project
#
# Mini Project Workflow:
#
# 1. Load Data: sns.load_dataset('iris') (Iris flowers dataset)
#
# 2. Correlation: Which variables have strongest relationship? (Heatmap)
#
# 3. Distribution: What is distribution of sepal_length? (Histplot)
#
# 4. Relationship: Show relationship between petal_length and petal_width colored by species. (Scatterplot)

# %%
# New dataset
df_iris = sns.load_dataset("iris")
print("\n--- Iris Dataset ---")
print(df_iris.head())

# Relationship visualization (Step 4)
plt.figure(figsize=(8, 6))
sns.scatterplot(
    data=df_iris,
    x="petal_length",
    y="petal_width",
    hue="species",  # Color by species category
    s=100,
    alpha=0.8,
)

plt.title("Petal Length vs Width Relationship (by Species)")
plt.legend(title="Flower Species")
plt.show()
# Out:
# --- Iris Dataset ---
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Key Takeaways:
#
# Matplotlib: Full control via Figure (Canvas) and Axes (Plot Area) concepts.
#
# Seaborn: More aesthetic plots with less code, built-in statistical calculations, and Pandas DataFrame integration.
#
# Toolkit: plot, scatter, bar, hist, boxplot, violinplot, heatmap, regplot, catplot.
